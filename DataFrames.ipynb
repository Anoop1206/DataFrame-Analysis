# %%
import pandas as pd
import matplotlib as plt

# %%
cd Desktop
# Out:
# [WinError 2] The system cannot find the file specified: 'Desktop'
# C:\Users\HP\Desktop

# %%
Employer = pd.read_excel("Data Analyst Talent Trial - Employer Review Data.xlsx")

# %%
Employer
# Out:
#      Date Submitted    Country        City  \
# 0        2022-01-04  Australia       Perth
# 1        2022-01-06  Australia    Adelaide
# 2        2022-01-06  Australia      Sydney
# 3        2022-01-08  Australia    Canberra
# 4        2022-01-10  Australia    Canberra
# ...             ...        ...         ...
# 1314     2022-05-27  Australia      Sydney
# 1315     2022-05-27  Australia  Kensington
# 1316     2022-05-28  Australia      Sydney
# 1317     2022-05-29  Indonesia    Semarang
# 1318     2022-05-29  Australia      Sydney
#
#                                 Company Sector  \
# 0                                       Health
# 1                                       Health
# 2                                       Health
# 3     Government & Public Service / Technology
# 4                  Government & Public Service
# ...                                        ...
# 1314                         Mining, Oil & Gas
# 1315                     Management Consulting
# ...

# %%
Employer.isnull().sum()
# Out:
# Date Submitted                                                                              0
# Country                                                                                     3
# City                                                                                       74
# Company Sector                                                                              0
# How long have you been with your current employer?                                         15
# What is your level of experience?                                                          18
# Gender                                                                                     15
# What is the highest level of education you have completed?                                 17
# Degree major                                                                               46
# How satisfied are you working at your company?                                             37
# ...

# %%
Employer.dropna(axis=0,inplace=True)

# %%
Employer
# Out:
#      Date Submitted    Country        City  \
# 2        2022-01-06  Australia      Sydney
# 3        2022-01-08  Australia    Canberra
# 5        2022-01-10  Australia    Canberra
# 6        2022-01-10  Australia    Canberra
# 7        2022-01-10  Australia    Brisbane
# ...             ...        ...         ...
# 1311     2022-05-27  Australia    Canberra
# 1312     2022-05-27  Australia     Gosford
# 1314     2022-05-27  Australia      Sydney
# 1315     2022-05-27  Australia  Kensington
# 1316     2022-05-28  Australia      Sydney
#
#                                 Company Sector  \
# 2                                       Health
# 3     Government & Public Service / Technology
# 5                  Government & Public Service
# 6                  Government & Public Service
# 7                                       Health
# ...                                        ...
# 1311               Government & Public Service
# 1312          Construction & Property Services
# ...

# %%
EMP=Employer.groupby('Gender')

# %%
EMP

# %%
EMP.get_group('Male')['Degree major'].value_counts()
# Out:
# Engineering & Mathematics             163
# Business & Management                 159
# IT & Computer Science                  52
# Law, Legal Studies & Justice           45
# Sciences                               20
# Humanities, Arts & Social Sciences     18
# Property & Built Environment           14
# Medical & Health Sciences               7
# Creative Arts                           2
# Name: Degree major, dtype: int64
